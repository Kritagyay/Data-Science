# %% [markdown]
# ##  Data Science Foundation

# %%
import pandas as pd

# %%
data=pd.read_csv("Dataset.csv")
data
# Out:
#    Unnamed: 0     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0     Ride ID           City   Rider ID  Ride Time  Ride Fare  Ride Date
# 1           1       New York        100         15         10   1/1/2022
# 2           2  San Francisco        101         30         25   1/1/2022
# 3           3    Los Angeles        102         45         30   1/1/2022
# 4           4       New York        103         20         15   1/1/2022
# 5           5  San Francisco        104         10          7   1/2/2022
# 6           6    Los Angeles        105         25         20   1/2/2022
# 7           7       New York        106         30         25   1/2/2022
# 8           8  San Francisco        107         15         10   1/2/2022
# 9           9    Los Angeles        108         50        NaN   1/3/2022
# 10         10       New York        109        NaN         20   1/3/2022
# 11         11  San Francisco        110         40         30   1/3/2022
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# count          24         24         24         20         21         23
# unique         24          4         24         10          7          8
# top       Ride ID   New York   Rider ID         15         25   1/1/2022
# freq            1          8          1          3          5          4
#
#        Unnamed: 6
# count          22
# unique          5
# top             9
# freq            6

# %%
data.columns=data.iloc[0]

# %%
data
# Out:
# 0   Ride ID           City  Rider ID  Ride Time  Ride Fare  Ride Date  \
# 0   Ride ID           City  Rider ID  Ride Time  Ride Fare  Ride Date
# 1         1       New York       100         15         10   1/1/2022
# 2         2  San Francisco       101         30         25   1/1/2022
# 3         3    Los Angeles       102         45         30   1/1/2022
# 4         4       New York       103         20         15   1/1/2022
# 5         5  San Francisco       104         10          7   1/2/2022
# 6         6    Los Angeles       105         25         20   1/2/2022
# 7         7       New York       106         30         25   1/2/2022
# 8         8  San Francisco       107         15         10   1/2/2022
# 9         9    Los Angeles       108         50        NaN   1/3/2022
# 10       10       New York       109        NaN         20   1/3/2022
# 11       11  San Francisco       110         40         30   1/3/2022
# ...

# %%
data.drop(index=0,axis=0,inplace=True)

# %%
data
# Out:
# 0  Ride ID           City Rider ID Ride Time Ride Fare Ride Date Ride Hour
# 1        1       New York      100        15        10  1/1/2022         9
# 2        2  San Francisco      101        30        25  1/1/2022        10
# 3        3    Los Angeles      102        45        30  1/1/2022        11
# 4        4       New York      103        20        15  1/1/2022        12
# 5        5  San Francisco      104        10         7  1/2/2022         9
# 6        6    Los Angeles      105        25        20  1/2/2022        10
# 7        7       New York      106        30        25  1/2/2022        11
# 8        8  San Francisco      107        15        10  1/2/2022        12
# 9        9    Los Angeles      108        50       NaN  1/3/2022         9
# 10      10       New York      109       NaN        20  1/3/2022        10
# 11      11  San Francisco      110        40        30  1/3/2022        11
# ...

# %%
data.mean()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11112\531903386.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# 0
# Ride ID     5.367686e+34
# Rider ID    4.352222e+66
# dtype: float64

# %%
data.fillna(0)
# Out:
# 0  Ride ID           City Rider ID Ride Time Ride Fare Ride Date Ride Hour
# 1        1       New York      100        15        10  1/1/2022         9
# 2        2  San Francisco      101        30        25  1/1/2022        10
# 3        3    Los Angeles      102        45        30  1/1/2022        11
# 4        4       New York      103        20        15  1/1/2022        12
# 5        5  San Francisco      104        10         7  1/2/2022         9
# 6        6    Los Angeles      105        25        20  1/2/2022        10
# 7        7       New York      106        30        25  1/2/2022        11
# 8        8  San Francisco      107        15        10  1/2/2022        12
# 9        9    Los Angeles      108        50         0  1/3/2022         9
# 10      10       New York      109         0        20  1/3/2022        10
# 11      11  San Francisco      110        40        30  1/3/2022        11
# ...

# %%
corr_coff = data["Ride Time"].corr(data["Ride Fare"])
print (corr_coff)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 corr_coff = data["Ride Time"].corr(data["Ride Fare"])
#       2 print (corr_coff)
#
# File ~\Desktop\sample_project_1\env\Lib\site-packages\pandas\core\series.py:2760, in Series.corr(self, other, method, min_periods)
#    2757     return np.nan
#    2759 if method in ["pearson", "spearman", "kendall"] or callable(method):
# -> 2760     return nanops.nancorr(
#    2761         this.values, other.values, method=method, min_periods=min_periods
#    2762     )
#    2764 raise ValueError(
#    2765     "method must be either 'pearson', "
#    2766     "'spearman', 'kendall', or a callable, "
#    2767     f"'{method}' was supplied"
#    2768 )
#
# File ~\Desktop\sample_project_1\env\Lib\site-packages\pandas\core\nanops.py:93, in disallow.__call__.<locals>._f(*args, **kwargs)
#      91 try:
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 1 to 23
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Ride ID    23 non-null     object
#  1   City       23 non-null     object
#  2   Rider ID   23 non-null     object
#  3   Ride Time  19 non-null     object
#  4   Ride Fare  20 non-null     object
#  5   Ride Date  22 non-null     object
#  6   Ride Hour  21 non-null     object
# dtypes: object(7)
# memory usage: 1.4+ KB
